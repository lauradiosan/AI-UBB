# %%
import csv
import matplotlib.pyplot as plt 
from math import log, sqrt

# %%
# load all the data from a csv file
def loadDataMoreInputs(fileName):
    data = []
    dataNames = []
    with open(fileName) as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        line_count = 0
        for row in csv_reader:
            if line_count < 2:
                dataNames = row
            else:
                data.append(row)
            line_count += 1
    return dataNames, data, line_count

# extract a particular feature (column)
def extractFeature(allData, names, featureName):
    pos = names.index(featureName)
    return [data[pos] for data in allData]

# plot a histogram for some data x
def plotDataHistogram(x, variableName):
    n, bins, patches = plt.hist(x, 20)
    plt.title('Histogram of ' + variableName)
    plt.show()

# %%
# clipping
# it helps of avoiding outliers
import os

crtDir =  os.getcwd()
filePath = os.path.join(crtDir, 'data', 'surveyDataSience.csv')

names, allData, noExamples = loadDataMoreInputs(filePath)
noFeatures = len(names)
print("features:   " , names)
print("no features: ", noFeatures)
print("noExamples:  ", noExamples)

pos1 = names.index('What is your gender? - Selected Choice')
print(pos1)
pos2 = names.index('In which country do you currently reside?')
print(pos2)
# Out:
# features:    ['Duration (in seconds)', 'What is your age (# years)?', 'What is your gender? - Selected Choice', 'In which country do you currently reside?', 'What is the highest level of formal education that you have attained or plan to attain within the next 2 years?', 'Select the title most similar to your current role (or most recent title if retired): - Selected Choice', 'For how many years have you been writing code and/or programming?', 'What programming languages do you use on a regular basis? (Select all that apply) - Selected Choice - Python', 'What programming languages do you use on a regular basis? (Select all that apply) - Selected Choice - R', 'What programming languages do you use on a regular basis? (Select all that apply) - Selected Choice - SQL', 'What programming languages do you use on a regular basis? (Select all that apply) - Selected Choice - C', 'What programming languages do you use on a regular basis? (Select all that apply) - Selected Choice - C++', 'What 
# ...

# %%
noIncompletedFeats = 0
for feature in names:
    data = extractFeature(allData, names, feature)
    # plotDataHistogram(data, feature)
    crtNoFeats = 0
    for el in data:
        if el != '':
            crtNoFeats += 1
    if (crtNoFeats < noFeatures):
        noIncompletedFeats += 1
        # print("feature: ", feature, " missing values: ", noFeatures - crtNoFeats)

print(noIncompletedFeats, " features have missing values")
# Out:
# 78  features have missing values

# %%
noIncompletedFeats = 0
for feature in names:
    data = extractFeature(allData, names, feature)
    # plotDataHistogram(data, feature)
    crtNoFeats = 0
    for el in data:
        if el != '':
            crtNoFeats += 1
    if (crtNoFeats < noFeatures):
        noIncompletedFeats += 1
        # print("feature: ", feature, " missing values: ", noFeatures - crtNoFeats)

print(noIncompletedFeats, " features have missing values")

education = extractFeature(allData, names, 'What is the highest level of formal education that you have attained or plan to attain within the next 2 years?')
print(education)

location = extractFeature(allData, names, 'In which country do you currently reside?')
gender = extractFeature(allData, names, 'What is your gender? - Selected Choice')

sum = 0
for ed in education:
    if (ed == 'Bachelorâ€™s degree'):
        sum += 3
    elif (ed == 'Masterâ€™s degree'):
        sum += 5
    elif (ed == 'Doctoral degree'):
        sum += 8
    
print("avg education: ", sum / len(education))

sum = 0
counter = 0
for elem in zip(education, location):
    if elem[1] == 'Romania':
        ed = elem[0]
        if (ed == 'Bachelorâ€™s degree'):
            sum += 3
        elif (ed == 'Masterâ€™s degree'):
            sum += 5
        elif (ed == 'Doctoral degree'):
            sum += 8
        counter += 1
print("avg education in Romania: ", sum / counter)

sum = 0
counter = 0
for elem in zip(education, location, gender):
    if (elem[2] == "Woman"):
        if elem[1] == 'Romania':
            ed = elem[0]
            if (ed == 'Bachelorâ€™s degree'):
                sum += 3
            elif (ed == 'Masterâ€™s degree'):
                sum += 5
            elif (ed == 'Doctoral degree'):
                sum += 8
            counter += 1
print("avg education in Romania for women: ", sum / counter)


# fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,5))
# ax1.hist(roomsPerPerson)
# ax1.set_title('room-pers histo')
# ax2.hist(roomsPerPersonClipped)
# ax2.set_title('room-pers-clipped histo')
# plt.show()
